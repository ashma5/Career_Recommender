# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import joblib
import matplotlib.pyplot as plt  # For plotting
import seaborn as sns           # For advanced visualizations
sns.set(style="whitegrid")      # Set style for seaborn

# %% [markdown]
# # Load Dataset

# %%
df1 = pd.read_csv("datasets/2.csv")

# %% [markdown]
# # Drop irrelevant columns

# %%
df = df1.drop(["id", "first_name", "last_name", "email", "part_time_job", "absence_days", "weekly_self_study_hours"], axis=1)

# %% [markdown]
# # Encode binary categorical features

# %%
df["gender"] = df["gender"].map({"male": 0, "female": 1})
df["extracurricular_activities"] = df["extracurricular_activities"].astype(int)

# %%
# making a copy of career_aspiration 
career_asp_cp = df["career_aspiration"]

# %%
print("\nClass Distribution:\n", df["career_aspiration"].value_counts())
# Out:
# Class Distribution:
#  career_aspiration
# Software Engineer        945
# Business Owner           927
# Unknown                  669
# Banker                   507
# Lawyer                   414
# Accountant               378
# Doctor                   357
# Real Estate Developer    249
# Stock Investor           219
# Construction Engineer    204
# Artist                   201
# Game Developer           189
# Government Officer       183
# Teacher                  177
# Designer                 168
# Scientist                117
# Writer                    96
# Name: count, dtype: int64

# %% [markdown]
# Dataset has a highly imbalanced class distribution for career_aspiration, with some classes (e.g., Software Engineer with 945 samples) having 10x more samples than others (e.g., Writer with only 96 samples). This imbalance can severely bias our model toward majority classes

# %% [markdown]
# # Encode target variable ("career_aspiration")

# %%
le_aspiration = LabelEncoder()
df["career_aspiration"] = le_aspiration.fit_transform(df["career_aspiration"])

# %%
df["career_aspiration"].value_counts()
# Out:
# career_aspiration
# 12    945
# 3     927
# 15    669
# 2     507
# 9     414
# 0     378
# 6     357
# 10    249
# 13    219
# 4     204
# 1     201
# 7     189
# 8     183
# 14    177
# 5     168
# 11    117
# 16     96
# Name: count, dtype: int64

# %% [markdown]
# # Summary of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gender                      6000 non-null   int64
#  1   extracurricular_activities  6000 non-null   int64
#  2   career_aspiration           6000 non-null   int64
#  3   math_score                  6000 non-null   int64
#  4   history_score               6000 non-null   int64
#  5   physics_score               6000 non-null   int64
#  6   chemistry_score             6000 non-null   int64
#  7   biology_score               6000 non-null   int64
#  8   english_score               6000 non-null   int64
#  9   geography_score             6000 non-null   int64
# dtypes: int64(10)
# memory usage: 468.9 KB

# %%
print(df.isnull().sum())
# Out:
# gender                        0
# extracurricular_activities    0
# career_aspiration             0
# math_score                    0
# history_score                 0
# physics_score                 0
# chemistry_score               0
# biology_score                 0
# english_score                 0
# geography_score               0
# dtype: int64

# %% [markdown]
# ## correlation analysis to see which subjects most influence career aspirations

# %%
numeric_cols = ['math_score', 'history_score', 'physics_score', 
               'chemistry_score', 'biology_score', 'english_score', 'geography_score']

# Use the ENCODED career column
correlation = df[numeric_cols + ['career_aspiration']].corr()['career_aspiration'].sort_values(ascending=False)

print("Correlation with Career Aspiration:\n", correlation.drop('career_aspiration'))

# Visualize
plt.figure(figsize=(10, 6))
sns.heatmap(df[numeric_cols + ['career_aspiration']].corr(), annot=True, cmap='coolwarm')
plt.title("Subject Scores vs. Career Aspiration Correlation")
plt.show()
# Out:
# Correlation with Career Aspiration:
#  biology_score      0.145754
# math_score         0.113359
# history_score      0.090362
# english_score      0.071737
# physics_score      0.060831
# chemistry_score    0.043061
# geography_score   -0.013847
# Name: career_aspiration, dtype: float64

# %% [markdown]
# Physics's low correlation (0.06) is unexpected. Check if it's career-specific

# %%
# Compare physics scores for medical vs engineering careers
#  0   gender                    
#  1   extracurricular_activities
#  2   career_aspiration         
#  3   math_score                
#  4   history_score             
#  5   physics_score             
#  6   chemistry_score           
#  7   biology_score             
#  8   english_score             
#  9   geography_score           
medical_careers = [6, 7]  #career codes
engineering_careers = [3, 5]  
print("Medical vs Engineering Physics Scores:")
print("Medical:", df[df['career_aspiration'].isin(medical_careers)]['physics_score'].mean())
print("Engineering:", df[df['career_aspiration'].isin(engineering_careers)]['physics_score'].mean())
# Out:
# Medical vs Engineering Physics Scores:
# Medical: 91.64285714285714
# Engineering: 75.66575342465754

# %%
df['career_name'] = le.inverse_transform(df['career_aspiration'])

plt.figure(figsize=(14, 7))
sns.boxplot(
    x='career_name',
    y='biology_score',
    data=df,
    order=sorted(df['career_name'].unique())
)
plt.title("Biology Scores by Career")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df['career_name'] = le.inverse_transform(df['career_aspiration'])

plt.figure(figsize=(14, 7))
sns.boxplot(
    x='career_name',
    y='physics_score',
    data=df,
    order=sorted(df['career_name'].unique())
)
plt.title("Physics Scores by Career")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
career_name = "Doctor"
career_code = le.transform([career_name])[0]
career_data = df[df['career_aspiration'] == career_code]
career_data[numeric_cols].mean().plot(kind='bar', title=f"Subject Averages for {career_name}")
plt.show()

# %%
career_name = "Game Developer"
career_code = le.transform([career_name])[0]
career_data = df[df['career_aspiration'] == career_code]
career_data[numeric_cols].mean().plot(kind='bar', title=f"Subject Averages for {career_name}")
plt.show()

# %% [markdown]
# # Define features (x) and target (y)

# %%
x = df.drop("career_aspiration", axis=1)
y = df["career_aspiration"]

# %% [markdown]
# # Split Dataset into train/test sets

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Train Model

# %%
params = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 6, None],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2']  # Better feature sampling
}
grid = GridSearchCV(RandomForestClassifier(class_weight='balanced'),
                   params, cv=5, n_jobs=-1)
grid.fit(x_train, y_train)
best_model = grid.best_estimator_

# %%
print(f"Best Accuracy: {grid.best_score_:.3f}")
# Out:
# Best Accuracy: 0.917

# %% [markdown]
# # Save Models & Label Encoders

# %%
# Save the best model
joblib.dump(best_model, 'best_rf_model.pkl')
# Out:
# ['best_rf_model.pkl']

# %%
# Save the label encoder (critical for decoding predictions)
joblib.dump(le_aspiration, 'label_encoder.pkl')
# Out:
# ['label_encoder.pkl']

# %%
# Save the complete GridSearchCV object
joblib.dump(grid, 'grid_search_results.pkl')
# Out:
# ['grid_search_results.pkl']
